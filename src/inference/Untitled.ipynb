# %%
import xarray as xr
# Out:
# Running cells with 'pytorch_xarray (Python 3.9.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/cluster/work/climate/kjeggle/venvs/pytorch_xarray/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
fp="/cluster/work/climate/dnikolo/IceCloudNet_Data/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20100101165742.131000000Z-NA.nat"

# %%
# read_seviri_native_file("/cluster/work/climate/dnikolo/IceCloudNet_Data/SEVIRI/MSG2-SEVI-MSG15-0100-NA-20100101165742.131000000Z-NA.nat")

# %%
import satpy
scn = satpy.Scene(filenames=[fp], reader='seviri_l1b_native')

# %%
scn.load(["IR_016", "IR_039", "IR_087", "IR_097", "IR_108",
                  "IR_120", "IR_134", "VIS006", "VIS008", "WV_062", "WV_073"])

# %%
# Get the coordinates
x_coord = scn["IR_016"].x.values.astype(np.float32)
y_coord = scn["IR_016"].y.values.astype(np.float32)

# %%
val_test = scn["VIS006"].values

# %%
ds = xr.Dataset(
            data_vars={
                "ch1": (["y", "x"],
                        scn["VIS006"].values.astype(np.float32),
                        scn["VIS006"].attrs),
                "ch2": (["y", "x"],
                "ch3": (["y", "x"],
                        scn["IR_016"].values.astype(np.float32),
                        scn["IR_016"].attrs),},
            coords={
                "x": (["x"], x_coord),
                "y": (["y"], y_coord),
                "sensing_start": (["sensing_start"], [scn.start_time]),
                "sensing_stop": (["sensing_stop"], \
                                 [pd.to_datetime(filepath.split('/')[-1].split('-')[-2].split('Z')[0],
                                                 format="%Y%m%d%H%M%S.%f").to_pydatetime()])
            },
            attrs={"source_file": os.path.basename(filepath)}
        )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 7
#       1 ds = xr.Dataset(
#       2             data_vars={
#       3                 "ch1": (["y", "x"],
#       4                         scn["VIS006"].values.astype(np.float32),
#       5                         scn["VIS006"].attrs),
#       6                 "ch2": (["y", "x"],
# ----> 7                         scn["VIS008"].values.astype(np.float32),
#       8                         scn["VIS008"].attrs),
#       9                 "ch3": (["y", "x"],
#      10                         scn["IR_016"].values.astype(np.float32),
#      11                         scn["IR_016"].attrs),},
#      12             coords={
#      13                 "x": (["x"], x_coord),
#      14                 "y": (["y"], y_coord),
#      15                 "sensing_start": (["sensing_start"], [scn.start_time]),
# ...

# %%
# todo - these functions are copied from code of the paper amell et al. 2021
from amell_et_al_data import read_seviri_native_file, _resolve_serialisation
